# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, IMAGE_SIZE)
    return img

# %%
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

# %% [markdown]
# ## Step1. 실험환경 set-up

# %%
BATCH_SIZE = 64
EPOCHS = 50

# %% [markdown]
# ## Step 2. 데이터 준비하기

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ## Step 3. 데이터 시각화

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE//4):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/16),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## Step 4. CNN 모델링

# %% [markdown]
# ### 1. Convolution filter, 채널 개수, activation, 모델 구조 변경

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation = 'relu', padding = 'same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation = 'relu', padding = 'same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation = 'relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = Sequential([
        Input(shape = (IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        Conv2D(16, 3, activation = 'relu', padding = 'same'),
        Conv2D(32, 3, activation = 'relu', padding = 'same'),
        MaxPool2D(),
        
        conv_block(64),
        conv_block(128),
        Dropout(0.3),
        
        conv_block(128),
        conv_block(256),
        Dropout(0.3),
        
        conv_block(256),
        conv_block(512),
        Dropout(0.3),
        
        Flatten(),
        dense_block(1024, 0.6),
        dense_block(256, 0.4),
        dense_block(64, 0.2),
        
        Dense(1, activation = 'sigmoid')
        
    ])
    
    return model

# %% [markdown]
# ### 2. BatchNorm만 사용

# %%
def conv_batch_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation = 'relu', padding = 'same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation = 'relu', padding = 'same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_batch_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation = 'relu'),
        tf.keras.layers.BatchNormalization(),
#         tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_batch_model():
    model = Sequential([
        Input(shape = (IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        Conv2D(16, 3, activation = 'relu', padding = 'same'),
        Conv2D(16, 3, activation = 'relu', padding = 'same'),
        MaxPool2D(),
        
        conv_batch_block(32),
        conv_batch_block(64),
        
        conv_batch_block(128),
#         Dropout(0.2),
        
        conv_batch_block(256),
#         Dropout(0.2),
        
        Flatten(),
        dense_batch_block(512, 0.7),
        dense_batch_block(128, 0.5),
        dense_batch_block(64, 0.3),
        
        Dense(1, activation = 'sigmoid')
        
    ])
    
    return model

# %% [markdown]
# ### 3. Dropout만 사용

# %%
def conv_drop_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation = 'relu', padding = 'same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation = 'relu', padding = 'same'),
#         tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_drop_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation = 'relu'),
#         tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_drop_model():
    model = Sequential([
        Input(shape = (IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        Conv2D(16, 3, activation = 'relu', padding = 'same'),
        Conv2D(16, 3, activation = 'relu', padding = 'same'),
        MaxPool2D(),
        
        conv_drop_block(32),
        conv_drop_block(64),
        
        conv_drop_block(128),
        Dropout(0.2),
        
        conv_drop_block(256),
        Dropout(0.2),
        
        Flatten(),
        dense_drop_block(512, 0.7),
        dense_drop_block(128, 0.5),
        dense_drop_block(64, 0.3),
        
        Dense(1, activation = 'sigmoid')
        
    ])
    
    return model

# %% [markdown]
# ## Step 5. 데이터 imbalance 처리

# %% [markdown]
# Class Weight 생략버전과 설정 버전 비교

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# ## Step 6. 모델 훈련, Step 7. 결과 확인과 시각화

# %% [markdown]
# ### 1. Convolution filter, 채널 개수, activation, 모델 구조 변경

# %% [markdown]
# With Weight

# %%
with tf.device('/GPU:0'):
    model = build_model()
    
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name = 'precision'),
        tf.keras.metrics.Recall(name = 'recall')
    ]
    
    model.compile(
        optimizer = 'Rmsprop',
        loss = 'binary_crossentropy',
        metrics = METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/50
# 65/65 [==============================] - 58s 741ms/step - loss: 0.7268 - accuracy: 0.6094 - precision: 0.8323 - recall: 0.5948 - val_loss: 0.6184 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch
# Epoch 43/50
# 65/65 [==============================] - 46s 718ms/step - loss: 0.0173 - accuracy: 0.9952 - precision: 0.9987 - recall: 0.9948 - val_loss: 0.0770 - val_accuracy: 0.9863 - val_precision: 0.9881 - val_recall: 0.9934
# Epoch 44/50
# 65/65 [==============================] - 47s 727ms/step - loss: 0.0217 - accuracy: 0.9937 - precision: 0.9987 - recall: 0.9929 - val_loss: 0.0535 - val_accuracy: 0.9873 - val_precision: 0.9894 - val_recall: 0.9934
# Epoch 45/50
# 65/65 [==============================] - 46s 720ms/step - loss: 0.0245 - accuracy: 0.9928 - precision: 0.9961 - recall: 0.9942 - val_loss: 0.0637 - val_accuracy: 0.9824 - val_precision: 0.9907 - val_recall: 0.9854
# Epoch 46/50
# 65/65 [==============================] - 47s 728ms/step - loss: 0.0226 - accuracy: 0.9921 - precision: 0.9968 - recall: 0.9926 - val_loss: 0.3132 - val_accuracy: 0.9160 - val_precision: 1.0000 - val_recall: 0.8859
# Epoch 47/50
# 65/65 [==============================] - 45s 704ms/step - loss: 0.0148 - accuracy: 0.9937 - precision: 0.9984 - recall: 0.9933 - val_loss: 0.0834 - val_accuracy: 0.9785 - val_precision: 0.9973 - val_recall: 0.9735
# Epoch 48/50
# 65/65 [==============================] - 47s 722ms/step - loss: 0.0213 - accuracy: 0.9950 - precision: 0.9974 - recall: 0.9958 - val_loss: 0.0691 - val_accuracy: 0.9824 - val_precision: 0.9868 - val_recall: 0.9894
# Epoch 49/50
# 65/65 [==============================] - 46s 719ms/step - loss: 0.0208 - accuracy: 0.9942 - precision: 0.9974 - recall: 0.9949 - val_loss: 0.1365 - val_accuracy: 0.9727 - val_precision: 0.9959 - val_recall: 0.9668
# Epoch 50/50
# 65/65 [==============================] - 47s 724ms/step - loss: 0.0215 - accuracy: 0.9923 - precision: 0.9980 - recall: 0.9916 - val_loss: 0.0530 - val_accuracy: 0.9844 - val_precision: 0.9907 - val_recall: 0.9880

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 10/10 [==============================] - 4s 384ms/step - loss: 1.6010 - accuracy: 0.7228 - precision: 0.6927 - recall: 1.0000
# Loss: 1.6010428667068481,
# Accuracy: 0.7227563858032227,
# Precision: 0.6927176117897034,
# Recall: 1.0

# %% [markdown]
# Without Weight

# %%
with tf.device('/GPU:0'):
    model = build_model()
    
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name = 'precision'),
        tf.keras.metrics.Recall(name = 'recall')
    ]
    
    model.compile(
        optimizer = 'Rmsprop',
        loss = 'binary_crossentropy',
        metrics = METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
#         class_weight=class_weight,
    )
# Out:
# Epoch 1/50
# 65/65 [==============================] - 60s 761ms/step - loss: 0.7929 - accuracy: 0.5582 - precision: 0.7483 - recall: 0.6114 - val_loss: 0.6207 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 2/50
# 65/65 [==============================] - 49s 753ms/step - loss: 0.3263 - accuracy: 0.8760 - precision: 0.9430 - recall: 0.8869 - val_loss: 0.6374 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 3/50
# 65/65 [==============================] - 49s 762ms/step - loss: 0.2512 - accuracy: 0.9084 - precision: 0.9389 - recall: 0.9380 - val_loss: 0.6254 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch
# 65/65 [==============================] - 46s 716ms/step - loss: 0.0178 - accuracy: 0.9945 - precision: 0.9961 - recall: 0.9965 - val_loss: 0.0877 - val_accuracy: 0.9805 - val_precision: 0.9893 - val_recall: 0.9840
# Epoch 45/50
# 65/65 [==============================] - 47s 733ms/step - loss: 0.0152 - accuracy: 0.9954 - precision: 0.9974 - recall: 0.9964 - val_loss: 0.0762 - val_accuracy: 0.9824 - val_precision: 0.9933 - val_recall: 0.9828
# Epoch 46/50
# 65/65 [==============================] - 46s 717ms/step - loss: 0.0114 - accuracy: 0.9962 - precision: 0.9971 - recall: 0.9977 - val_loss: 0.0940 - val_accuracy: 0.9775 - val_precision: 0.9815 - val_recall: 0.9880
# Epoch 47/50
# 65/65 [==============================] - 47s 722ms/step - loss: 0.0144 - accuracy: 0.9954 - precision: 0.9968 - recall: 0.9971 - val_loss: 0.1017 - val_accuracy: 0.9766 - val_precision: 0.9919 - val_recall: 0.9761
# Epoch 48/50
# 65/65 [==============================] - 46s 710ms/step - loss: 0.0204 - accuracy: 0.9945 - precision: 0.9961 - recall: 0.9964 - val_loss: 0.0702 - val_accuracy: 0.9736 - val_precision: 0.9738 - val_recall: 0.9907
# Epoch 49/50
# 65/65 [==============================] - 47s 725ms/step - loss: 0.0149 - accuracy: 0.9945 - precision: 0.9958 - recall: 0.9968 - val_loss: 0.1664 - val_accuracy: 0.9502 - val_precision: 0.9380 - val_recall: 0.9987
# Epoch 50/50
# 65/65 [==============================] - 46s 716ms/step - loss: 0.0111 - accuracy: 0.9962 - precision: 0.9971 - recall: 0.9977 - val_loss: 0.0937 - val_accuracy: 0.9814 - val_precision: 0.9946 - val_recall: 0.9801

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 10/10 [==============================] - 4s 411ms/step - loss: 1.2354 - accuracy: 0.8173 - precision: 0.7794 - recall: 0.9872
# Loss: 1.2353757619857788,
# Accuracy: 0.817307710647583,
# Precision: 0.7793522477149963,
# Recall: 0.9871794581413269

# %% [markdown]
# ### 2. BatchNorm만 사용

# %% [markdown]
# with weights

# %%
with tf.device('/GPU:0'):
    model = build_batch_model()
    
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name = 'precision'),
        tf.keras.metrics.Recall(name = 'recall')
    ]
    
    model.compile(
        optimizer = 'Adam',
        loss = 'binary_crossentropy',
        metrics = METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/50
# 65/65 [==============================] - 56s 709ms/step - loss: 0.2283 - accuracy: 0.9038 - precision: 0.9720 - recall: 0.8965 - val_loss: 0.5781 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 2/50
# 65/65 [==============================] - 47s 731ms/step - loss: 0.1118 - accuracy: 0.9630 - precision: 0.9897 - recall: 0.9602 - val_loss: 0.6363 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 3/50
# 65/65 [==============================] - 47s 725ms/step - loss: 0.1097 - accuracy: 0.9635 - precision: 0.9868 - recall: 0.9638 - val_loss: 0.6926 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 4/50
# 65/65 [==============================] - 49s 755ms/step - loss: 0.0971 - accuracy: 0.9642 - precision: 0.9881 - recall: 0.9635 - val_loss: 0.7634 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 5/50
# 65/65 [==============================] - 52s 804ms/step - loss: 0.0825 - accuracy: 0.9695 - precision: 0.9901 - recall: 0.9686 - val_loss: 0.8415 - val_accuracy: 0.7383 - val_precision: 0.7383 - val_recall: 1.0000
# Epoch 6/50
# 65/65 [==============================] - 45s 706ms/step - loss: 0.0666 - accuracy: 0.9781 - precision: 0.9922 - recall: 0.9784 - val_loss: 1.0131 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch
# Epoch 47/50
# 65/65 [==============================] - 45s 695ms/step - loss: 0.0097 - accuracy: 0.9969 - precision: 0.9993 - recall: 0.9964 - val_loss: 0.0701 - val_accuracy: 0.9775 - val_precision: 0.9803 - val_recall: 0.9894
# Epoch 48/50
# 65/65 [==============================] - 44s 689ms/step - loss: 0.0063 - accuracy: 0.9983 - precision: 0.9994 - recall: 0.9984 - val_loss: 0.0984 - val_accuracy: 0.9775 - val_precision: 0.9946 - val_recall: 0.9747
# Epoch 49/50
# 65/65 [==============================] - 45s 698ms/step - loss: 0.0079 - accuracy: 0.9976 - precision: 0.9993 - recall: 0.9974 - val_loss: 0.2239 - val_accuracy: 0.9492 - val_precision: 0.9397 - val_recall: 0.9947
# Epoch 50/50
# 65/65 [==============================] - 44s 688ms/step - loss: 0.0110 - accuracy: 0.9964 - precision: 0.9990 - recall: 0.9961 - val_loss: 0.4341 - val_accuracy: 0.9121 - val_precision: 0.9985 - val_recall: 0.8818

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 10/10 [==============================] - 5s 479ms/step - loss: 0.7051 - accuracy: 0.8510 - precision: 0.8817 - recall: 0.8795
# Loss: 0.7050574421882629,
# Accuracy: 0.8509615659713745,
# Precision: 0.8817480802536011,
# Recall: 0.879487156867981

# %% [markdown]
# # ACC 85%!!

# %% [markdown]
# without weights

# %%
with tf.device('/GPU:0'):
    model = build_batch_model()
    
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name = 'precision'),
        tf.keras.metrics.Recall(name = 'recall')
    ]
    
    model.compile(
        optimizer = 'Adam',
        loss = 'binary_crossentropy',
        metrics = METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
#         class_weight=class_weight,
    )
# Out:
# Epoch 1/50
# 65/65 [==============================] - 56s 723ms/step - loss: 0.2130 - accuracy: 0.9317 - precision: 0.9731 - recall: 0.9342 - val_loss: 0.6084 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 2/50
# 65/65 [==============================] - 47s 723ms/step - loss: 0.1196 - accuracy: 0.9608 - precision: 0.9744 - recall: 0.9728 - val_loss: 0.5809 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 3/50
# 65/65 [==============================] - 48s 740ms/step - loss: 0.0894 - accuracy: 0.9702 - precision: 0.9778 - recall: 0.9823 - val_loss: 0.6279 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 4/50
# 65/65 [==============================] - 49s 757ms/step - loss: 0.0672 - accuracy: 0.9798 - precision: 0.9877 - recall: 0.9851 - val_loss: 0.7755 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 5/50
# 65/65 [==============================] - 51s 786ms/step - loss: 0.0686 - accuracy: 0.9755 - precision: 0.9826 - recall: 0.9845 - val_loss: 0.9659 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 6/50
# 65/65 [==============================] - 46s 712ms/step - loss: 0.0719 - accuracy: 0.9767 - precision: 0.9817 - recall: 0.9871 - val_loss: 1.0227 - val_accuracy: 0.7383 - val_precision: 0.7383 - val_recall: 1.0000
# Epoch 7/50
# 65/65 [==============================] - 46s 707ms/step - loss: 0.0487 - accuracy: 0.9834 - precision: 0.9871 - recall: 0.9906 - val_loss: 1.0741 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 8/50
# 65/65 [==============================] - 45s 694ms/step - loss: 0.0465 - accuracy: 0.9841 - precision: 0.9894 - recall: 0.9894 - val_loss: 1.1037 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch
50
# 65/65 [==============================] - 45s 696ms/step - loss: 0.0133 - accuracy: 0.9962 - precision: 0.9967 - recall: 0.9980 - val_loss: 0.1092 - val_accuracy: 0.9688 - val_precision: 0.9958 - val_recall: 0.9612
# Epoch 49/50
# 65/65 [==============================] - 43s 670ms/step - loss: 0.0106 - accuracy: 0.9974 - precision: 0.9990 - recall: 0.9974 - val_loss: 0.0941 - val_accuracy: 0.9717 - val_precision: 0.9677 - val_recall: 0.9947
# Epoch 50/50
# 65/65 [==============================] - 44s 677ms/step - loss: 0.0075 - accuracy: 0.9976 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0825 - val_accuracy: 0.9854 - val_precision: 0.9907 - val_recall: 0.9894

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 10/10 [==============================] - 4s 390ms/step - loss: 1.4699 - accuracy: 0.7644 - precision: 0.7288 - recall: 0.9923
# Loss: 1.4699183702468872,
# Accuracy: 0.7644230723381042,
# Precision: 0.7288135886192322,
# Recall: 0.9923076629638672

# %% [markdown]
# ### 3. Dropout만 사용

# %% [markdown]
# with weights

# %%
with tf.device('/GPU:0'):
    model = build_drop_model()
    
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name = 'precision'),
        tf.keras.metrics.Recall(name = 'recall')
    ]
    
    model.compile(
        optimizer = 'Adam',
        loss = 'binary_crossentropy',
        metrics = METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/50
# 65/65 [==============================] - 57s 743ms/step - loss: 0.6942 - accuracy: 0.4954 - precision: 0.7393 - recall: 0.4968 - val_loss: 0.6987 - val_accuracy: 0.2676 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/50
# 65/65 [==============================] - 46s 721ms/step - loss: 0.6924 - accuracy: 0.3810 - precision: 0.7294 - recall: 0.2688 - val_loss: 0.6942 - val_accuracy: 0.2676 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/50
# 65/65 [==============================] - 47s 733ms/step - loss: 0.6942 - accuracy: 0.3853 - precision: 0.7178 - recall: 0.2847 - val_loss: 0.6915 - val_accuracy: 0.7383 - val_precision: 0.7383 - val_recall: 1.0000
# Epoch 4/50
# 65/65 [==============================] - 49s 760ms/step - loss: 0.6928 - accuracy: 0.4356 - precision: 0.7457 - recall: 0.3666 - val_loss: 0.6929 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 5/50
# 65/65 [==============================] - 52s 804ms/step - loss: 0.6915 - accuracy: 0.5106 - precision: 0.7385 - recall: 0.5324 - val_loss: 0.6902 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 6/50
# 65/65 [==============================] - 45s 692ms/step - loss: 0.6947 - accuracy: 0.4082 - precision: 0.7386 - recall: 0.3138 - val_loss: 0.6952 - val_accuracy: 0.2637 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/50
# 65/65 [==============================] - 46s 708ms/step - loss: 0.6940 - accuracy: 0.5075 - precision: 0.7470 - recall: 0.5094 - val_loss: 0.6935 - val_accuracy: 0.2607 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/50
# 65/65 [==============================] - 44s 686ms/step - loss: 0.6960 - accuracy: 0.4457 - precision: 0.7333 - recall: 0.3960 - val_loss: 0.6902 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 9/50
# 65/65 [==============================] - 45s 698ms/step - loss: 0.6892 - accuracy: 0.5748 - precision: 0.7514 - recall: 0.6449 - val_loss: 0.6895 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 10/50
# 65/65 [==============================] - 43s 661ms/step - loss: 0.6963 - accuracy: 0.5274 - precision: 0.7439 - recall: 0.5516 - val_loss: 0.6951 - val_accuracy: 0.2666 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11
- val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 45/50
# 65/65 [==============================] - 45s 707ms/step - loss: 0.6913 - accuracy: 0.4697 - precision: 0.7341 - recall: 0.4536 - val_loss: 0.6919 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 46/50
# 65/65 [==============================] - 44s 684ms/step - loss: 0.6927 - accuracy: 0.5647 - precision: 0.7425 - recall: 0.6358 - val_loss: 0.6916 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 47/50
# 65/65 [==============================] - 45s 697ms/step - loss: 0.6980 - accuracy: 0.4450 - precision: 0.7374 - recall: 0.3857 - val_loss: 0.6951 - val_accuracy: 0.2676 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/50
# 65/65 [==============================] - 45s 699ms/step - loss: 0.6876 - accuracy: 0.4668 - precision: 0.7479 - recall: 0.4364 - val_loss: 0.6909 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 49/50
# 65/65 [==============================] - 44s 684ms/step - loss: 0.6961 - accuracy: 0.5500 - precision: 0.7328 - recall: 0.6177 - val_loss: 0.6927 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 50/50
# 65/65 [==============================] - 44s 681ms/step - loss: 0.6928 - accuracy: 0.4168 - precision: 0.7442 - recall: 0.3298 - val_loss: 0.6950 - val_accuracy: 0.2666 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 10/10 [==============================] - 4s 399ms/step - loss: 0.6942 - accuracy: 0.3750 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss: 0.6941545009613037,
# Accuracy: 0.375,
# Precision: 0.0,
# Recall: 0.0

# %% [markdown]
# without weights

# %%
with tf.device('/GPU:0'):
    model = build_drop_model()
    
    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name = 'precision'),
        tf.keras.metrics.Recall(name = 'recall')
    ]
    
    model.compile(
        optimizer = 'Adam',
        loss = 'binary_crossentropy',
        metrics = METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
#         class_weight=class_weight,
    )
# Out:
# Epoch 1/50
# 65/65 [==============================] - 53s 706ms/step - loss: 0.5985 - accuracy: 0.7370 - precision: 0.7441 - recall: 0.9851 - val_loss: 0.5799 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 2/50
# 65/65 [==============================] - 47s 722ms/step - loss: 0.5801 - accuracy: 0.7437 - precision: 0.7437 - recall: 1.0000 - val_loss: 0.5761 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 3/50
# 65/65 [==============================] - 47s 737ms/step - loss: 0.5791 - accuracy: 0.7442 - precision: 0.7442 - recall: 1.0000 - val_loss: 0.5829 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 4/50
# 65/65 [==============================] - 49s 759ms/step - loss: 0.5753 - accuracy: 0.7454 - precision: 0.7454 - recall: 1.0000 - val_loss: 0.5811 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 5/50
# 65/65 [==============================] - 51s 796ms/step - loss: 0.5747 - accuracy: 0.7433 - precision: 0.7433 - recall: 1.0000 - val_loss: 0.5780 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 6/50
# 65/65 [==============================] - 45s 705ms/step - loss: 0.5725 - accuracy: 0.7437 - precision: 0.7437 - recall: 1.0000 - val_loss: 0.5793 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 7/50
# 65/65 [==============================] - 45s 692ms/step - loss: 0.5750 - accuracy: 0.7416 - precision: 0.7416 - recall: 1.0000 - val_loss: 0.5785 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 8/50
# 65/65 [==============================] - 45s 695ms/step - loss: 0.5686 - accuracy: 0.7459 - precision: 0.7459 - recall: 1.0000 - val_loss: 0.5802 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000accurac
# Epoch 9/50
# 65/65 [==============================] - 44s 680ms/step - loss: 0.5734 - accuracy: 0.7435 - precision: 0.7435 - recall: 1.0000 - val_loss: 0.5819 - val_accuracy: 0.7314 - val_precision: 0.7314 - val_recall: 1.0000
# Epoch 10/50
# 65/65 [==============================] - 45s 705ms/step - loss: 0.5724 - accuracy: 0.7418 - precision: 0.7418 - recall: 1.0000 - val_loss: 0.5789 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 11/50
# 65/65 [==============================] - 44s 677ms/step - loss: 0.5688 - accuracy: 0.7462 - precision: 0.7462 - recall: 1.0000 - val_loss: 0.5772 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 12/50
# 65/65 [==============================] - 44s 681ms/step - loss: 0.5742 - accuracy: 0.7411 - precision: 0.7411 - recall: 1.0000 - val_loss: 0.5809 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 13/50
# 65/65 [==============================] - 45s 696ms/step - loss: 0.5688 - accuracy: 0.7457 - precision: 0.7457 - recall: 1.0000 - val_loss: 0.5810 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 14/50
# 65/65 [==============================] - 45s 697ms/step - loss: 0.5690 - accuracy: 0.7474 - precision: 0.7474 - recall: 1.0000 - val_loss: 0.5762 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 15/50
# 65/65 [==============================] - 44s 680ms/step - loss: 0.5758 - accuracy: 0.7406 - precision: 0.7406 - recall: 1.0000 - val_loss: 0.5739 - val_accuracy: 0.7393 - val_precision: 0.7393 - val_recall: 1.0000
# Epoch 16/50
# 65/65 [==============================] - 45s 692ms/step - loss: 0.5748 - accuracy: 0.7425 - precision: 0.7425 - recall: 1.0000 - val_loss: 0.5782 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 17/50
# 65/65 [==============================] - 43s 666ms/step - loss: 0.5693 - accuracy: 0.7447 - precision: 0.7447 - recall: 1.0000 - val_loss: 0.5759 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 18/50
# 65/65 [==============================] - 44s 689ms/step - loss: 0.5701 - accuracy: 0.7442 - precision: 0.7442 - recall: 1.0000 - val_loss: 0.5769 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 19/50
# 65/65 [==============================] - 44s 684ms/step - loss: 0.5706 - accuracy: 0.7452 - precision: 0.7452 - recall: 1.0000 - val_loss: 0.5809 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 20/50
# 65/65 [==============================] - 44s 682ms/step - loss: 0.5719 - accuracy: 0.7428 - precision: 0.7428 - recall: 1.0000 - val_loss: 0.5819 - val_accuracy: 0.7314 - val_precision: 0.7314 - val_recall: 1.0000
# Epoch 21/50
# 65/65 [==============================] - 44s 689ms/step - loss: 0.5731 - accuracy: 0.7425 - precision: 0.7425 - recall: 1.0000 - val_loss: 0.5791 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 22/50
# 65/65 [==============================] - 44s 676ms/step - loss: 0.5712 - accuracy: 0.7430 - precision: 0.7430 - recall: 1.0000 - val_loss: 0.5819 - val_accuracy: 0.7314 - val_precision: 0.7314 - val_recall: 1.0000
# Epoch 23/50
# 65/65 [==============================] - 45s 692ms/step - loss: 0.5681 - accuracy: 0.7454 - precision: 0.7454 - recall: 1.0000 - val_loss: 0.5791 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 24/50
# 65/65 [==============================] - 45s 692ms/step - loss: 0.5669 - accuracy: 0.7478 - precision: 0.7478 - recall: 1.0000 - val_loss: 0.5748 - val_accuracy: 0.7383 - val_precision: 0.7383 - val_recall: 1.0000
# Epoch 25/50
# 65/65 [==============================] - 44s 681ms/step - loss: 0.5752 - accuracy: 0.7389 - precision: 0.7389 - recall: 1.0000 - val_loss: 0.5789 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 26/50
# 65/65 [==============================] - 43s 672ms/step - loss: 0.5728 - accuracy: 0.7425 - precision: 0.7425 - recall: 1.0000 - val_loss: 0.5769 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 27/50
# 65/65 [==============================] - 43s 666ms/step - loss: 0.5664 - accuracy: 0.7498 - precision: 0.7498 - recall: 1.0000 - val_loss: 0.5789 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 28/50
# 65/65 [==============================] - 45s 694ms/step - loss: 0.5726 - accuracy: 0.7409 - precision: 0.7409 - recall: 1.0000 - val_loss: 0.5749 - val_accuracy: 0.7383 - val_precision: 0.7383 - val_recall: 1.0000
# Epoch 29/50
# 65/65 [==============================] - 44s 683ms/step - loss: 0.5723 - accuracy: 0.7428 - precision: 0.7428 - recall: 1.0000 - val_loss: 0.5808 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 30/50
# 65/65 [==============================] - 44s 677ms/step - loss: 0.5686 - accuracy: 0.7454 - precision: 0.7454 - recall: 1.0000 - val_loss: 0.5769 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 31/50
# 65/65 [==============================] - 45s 701ms/step - loss: 0.5695 - accuracy: 0.7442 - precision: 0.7442 - recall: 1.0000 - val_loss: 0.5789 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 32/50
# 65/65 [==============================] - 44s 679ms/step - loss: 0.5724 - accuracy: 0.7421 - precision: 0.7421 - recall: 1.0000 - val_loss: 0.5799 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 33/50
# 65/65 [==============================] - 44s 687ms/step - loss: 0.5707 - accuracy: 0.7437 - precision: 0.7437 - recall: 1.0000 - val_loss: 0.5809 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 34/50
# 65/65 [==============================] - 44s 686ms/step - loss: 0.5732 - accuracy: 0.7413 - precision: 0.7413 - recall: 1.0000 - val_loss: 0.5793 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000: 0.5799 - accuracy: 0
# Epoch 35/50
# 65/65 [==============================] - 44s 690ms/step - loss: 0.5669 - accuracy: 0.7466 - precision: 0.7466 - recall: 1.0000 - val_loss: 0.5780 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 36/50
# 65/65 [==============================] - 45s 702ms/step - loss: 0.5699 - accuracy: 0.7445 - precision: 0.7445 - recall: 1.0000 - val_loss: 0.5748 - val_accuracy: 0.7383 - val_precision: 0.7383 - val_recall: 1.0000
# Epoch 37/50
# 65/65 [==============================] - 45s 695ms/step - loss: 0.5728 - accuracy: 0.7423 - precision: 0.7423 - recall: 1.0000 - val_loss: 0.5759 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 1.0000
# Epoch 38/50
# 65/65 [==============================] - 44s 686ms/step - loss: 0.5699 - accuracy: 0.7442 - precision: 0.7442 - recall: 1.0000 - val_loss: 0.5780 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 39/50
# 65/65 [==============================] - 43s 668ms/step - loss: 0.5721 - accuracy: 0.7421 - precision: 0.7421 - recall: 1.0000 - val_loss: 0.5779 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 40/50
# 65/65 [==============================] - 44s 683ms/step - loss: 0.5687 - accuracy: 0.7471 - precision: 0.7471 - recall: 1.0000 - val_loss: 0.5769 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 41/50
# 65/65 [==============================] - 44s 687ms/step - loss: 0.5728 - accuracy: 0.7428 - precision: 0.7428 - recall: 1.0000 - val_loss: 0.5790 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 42/50
# 65/65 [==============================] - 43s 670ms/step - loss: 0.5718 - accuracy: 0.7423 - precision: 0.7423 - recall: 1.0000 - val_loss: 0.5779 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 43/50
# 65/65 [==============================] - 43s 675ms/step - loss: 0.5674 - accuracy: 0.7469 - precision: 0.7469 - recall: 1.0000 - val_loss: 0.5771 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 44/50
# 65/65 [==============================] - 43s 664ms/step - loss: 0.5687 - accuracy: 0.7452 - precision: 0.7452 - recall: 1.0000 - val_loss: 0.5770 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 45/50
# 65/65 [==============================] - 44s 683ms/step - loss: 0.5771 - accuracy: 0.7368 - precision: 0.7368 - recall: 1.0000 - val_loss: 0.5779 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 46/50
# 65/65 [==============================] - 43s 671ms/step - loss: 0.5683 - accuracy: 0.7466 - precision: 0.7466 - recall: 1.0000 - val_loss: 0.5769 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 47/50
# 65/65 [==============================] - 44s 681ms/step - loss: 0.5692 - accuracy: 0.7450 - precision: 0.7450 - recall: 1.0000 - val_loss: 0.5799 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 48/50
# 65/65 [==============================] - 43s 675ms/step - loss: 0.5730 - accuracy: 0.7411 - precision: 0.7411 - recall: 1.0000 - val_loss: 0.5779 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000s: 0.5934 - accuracy: 0.7214 - precision: 0.7214 - recall: 1.00 - ETA: 12s -
# Epoch 49/50
# 65/65 [==============================] - 45s 697ms/step - loss: 0.5672 - accuracy: 0.7486 - precision: 0.7486 - recall: 1.0000 - val_loss: 0.5769 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 50/50
# 65/65 [==============================] - 42s 656ms/step - loss: 0.5702 - accuracy: 0.7440 - precision: 0.7440 - recall: 1.0000 - val_loss: 0.5770 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 10/10 [==============================] - 4s 412ms/step - loss: 0.6952 - accuracy: 0.6250 - precision: 0.6250 - recall: 1.0000
# Loss: 0.6951729655265808,
# Accuracy: 0.625,
# Precision: 0.625,
# Recall: 1.0

# %% [markdown]
# ## 총 3가지 경우에 대해 weight  유뮤로 비교한 결과

# %% [markdown]
# 1. 모델의 파라미터수를 증가시킨 1번 모델은 weight를 주지 않은 모델이 더 좋은 결과를 보인다. 이는 학습 데이터에 어느정도 과적합이 되지 않았을까 하는 의심을 할 수 있다.
# 2. BatchNorm만을 사용한 2번 모델에서 Weight를 준 경우의 accuracy가 85%가까이 나오면서 더 좋은 성능을 보였다. acc와 precision은 증가하였으나 recall값은 감소한 것을 볼 수 있는데, 어느정도 일반화된 모델로 생각된다.
# 3. Dropout만을 사용한 3번 모델은 학습이 제대로 되지 않았다.
