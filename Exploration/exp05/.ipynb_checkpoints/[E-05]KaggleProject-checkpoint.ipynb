# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np

import missingno as msno

from sklearn.ensemble import RandomForestRegressor, VotingRegressor, AdaBoostRegressor
from sklearn.model_selection import KFold, cross_val_score, train_test_split, GridSearchCV
from lightgbm import LGBMRegressor

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import seaborn as sns

# %%
data_dir = os.getenv('HOME')+'/aiffel/exp5/data'

train_data_path = join(data_dir, 'train.csv')
test_data_path = join(data_dir, 'test.csv')      # 테스트, 즉 submission 시 사용할 데이터 경로

print(train_data_path)
print(test_data_path)
# Out:
# /aiffel/aiffel/exp5/data/train.csv
# /aiffel/aiffel/exp5/data/test.csv

# %%
train = pd.read_csv(train_data_path)
test = pd.read_csv(test_data_path)

# %%
train.head()
# Out:
#    id             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0   0  20141013T000000  221900.0         3       1.00         1180      5650
# 1   1  20150225T000000  180000.0         2       1.00          770     10000
# 2   2  20150218T000000  510000.0         3       2.00         1680      8080
# 3   3  20140627T000000  257500.0         3       2.25         1715      6819
# 4   4  20150115T000000  291850.0         3       1.50         1060      9711
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     1.0           0     0  ...      6         770              0      1933
# 2     1.0           0     0  ...      8        1680              0      1987
# 3     2.0           0     0  ...      7        1715              0      1995
# 4     1.0           0     0  ...      7        1060              0      1963
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1             0    98028  47.7379 -122.233           2720        8062
# 2             0    98074  47.6168 -122.045           1800        7503
# 3             0    98003  47.3097 -122.327           2238        6819
# 4             0    98198  47.4095 -122.315           1650        9711
#
# [5 rows x 21 columns]

# %% [markdown]
# 1. ID : 집을 구분하는 번호
# 2. date : 집을 구매한 날짜
# 3. price : 타겟 변수인 집의 가격
# 4. bedrooms : 침실의 수
# 5. bathrooms : 침실당 화장실 개수
# 6. sqft_living : 주거 공간의 평방 피트
# 7. sqft_lot : 부지의 평방 피트
# 8. floors : 집의 층 수
# 9. waterfront : 집의 전방에 강이 흐르는지 유무 (a.k.a. 리버뷰)
# 10. view : 집이 얼마나 좋아 보이는지의 정도
# 11. condition : 집의 전반적인 상태
# 12. grade : King County grading 시스템 기준으로 매긴 집의 등급
# 13. sqft_above : 지하실을 제외한 평방 피트
# 14. sqft_basement : 지하실의 평방 피트
# 15. yr_built : 집을 지은 년도
# 16. yr_renovated : 집을 재건축한 년도
# 17. zipcode : 우편번호
# 18. lat : 위도
# 19. long : 경도
# 20. sqft_living15 : 2015년 기준 주거 공간의 평방 피트(집을 재건축했다면, 변화가 있을 수 있음)
# 21. sqft_lot15 : 2015년 기준 부지의 평방 피트(집을 재건축했다면, 변화가 있을 수 있음)

# %% [markdown]
# ## 데이터 전처리 계획(insight 만을 이용)
# 1. date -> year, month로 구분
# 2. zipcode 위도, 경도 전처리 혹은 제거
# 3. 15년도 이후 데이터를 기준으로 진행. sqft_living과 sqft_lot 데이터 제거
# 4. 지어진 년도와 재건축 년도를 이용하여 집이 몇년 되었는지 계산하는 변수로 변형

# %% [markdown]
# #### 1. date -> year, month, weekday

# %%
train['date'] = train['date'].apply(lambda i: i[:8])

# %%
train['date'] = pd.to_datetime(train['date'])

# %%
train['year'] = train['date'].dt.year
train['month'] = train['date'].dt.month
train['weekday'] = train['date'].dt.weekday

# %%
train.drop('id', inplace = True, axis = 1)
train.drop('date', inplace = True, axis = 1)

# %% [markdown]
# #### 2. zipcode 제거

# %%
train.drop('zipcode', inplace = True, axis = 1)

# %% [markdown]
# #### 3. 15년 이후 데이터 사용

# %%
train.drop('sqft_living', inplace = True, axis = 1)
train.drop('sqft_lot', inplace = True, axis = 1)

# %% [markdown]
# #### 4. 재건축에 대한 정보 변경

# %%
train['house_year'] = train['yr_renovated']

# %%
for i in range(len(train)):
    train['house_year'][i] = 2022 - max(train['yr_renovated'][i], train['yr_built'][i])

# %%
train[train['yr_renovated'] != 0][['house_year','yr_built','yr_renovated']]
# Out:
#        house_year  yr_built  yr_renovated
# 26             20      1930          2002
# 78             23      1900          1999
# 149            31      1957          1991
# 160            44      1915          1978
# 166            17      1904          2005
# ...           ...       ...           ...
# 13626           8      1965          2014
# 13641          18      1944          2004
# 13952          16      1977          2006
# 14218          13      1962          2009
# 14220           8      1971          2014
#
# [631 rows x 3 columns]

# %%
train['renovated'] = train['yr_renovated'] != 0

# %%
train.drop('yr_renovated', inplace = True, axis = 1)
train.drop('yr_built', inplace = True, axis = 1)

# %%
train.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'floors', 'waterfront', 'view',
#        'condition', 'grade', 'sqft_above', 'sqft_basement', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month', 'weekday', 'house_year',
#        'renovated'],
#       dtype='object')

# %%
train.head()
# Out:
#       price  bedrooms  bathrooms  floors  waterfront  view  condition  grade  \
# 0  221900.0         3       1.00     1.0           0     0          3      7
# 1  180000.0         2       1.00     1.0           0     0          3      6
# 2  510000.0         3       2.00     1.0           0     0          3      8
# 3  257500.0         3       2.25     2.0           0     0          3      7
# 4  291850.0         3       1.50     1.0           0     0          3      7
#
#    sqft_above  sqft_basement      lat     long  sqft_living15  sqft_lot15  \
# 0        1180              0  47.5112 -122.257           1340        5650
# 1         770              0  47.7379 -122.233           2720        8062
# 2        1680              0  47.6168 -122.045           1800        7503
# 3        1715              0  47.3097 -122.327           2238        6819
# 4        1060              0  47.4095 -122.315           1650        9711
#
#    year  month  weekday  house_year  renovated
# 0  2014     10        0          67      False
# 1  2015      2        2          89      False
# 2  2015      2        2          35      False
# 3  2014      6        4          27      False
# 4  2015      1        3          59      False

# %% [markdown]
# #### test 데이터에도 train 데이터와 같은 작업 진행

# %%
test['date'] = test['date'].apply(lambda i: i[:8])
test['date'] = pd.to_datetime(test['date'])
test['year'] = test['date'].dt.year
test['month'] = test['date'].dt.month
test['weekday'] = test['date'].dt.weekday
test.drop('id', inplace = True, axis = 1)
test.drop('date', inplace = True, axis = 1)
test.drop('zipcode', inplace = True, axis = 1)
test.drop('sqft_living', inplace = True, axis = 1)
test.drop('sqft_lot', inplace = True, axis = 1)

# %%
test['house_year'] = test['yr_renovated']
for i in range(len(test)):
    test['house_year'][i] = 2022 - max(test['yr_renovated'][i], test['yr_built'][i])
    
test['renovated'] = test['yr_renovated'] != 0
test.drop('yr_renovated', inplace = True, axis = 1)
test.drop('yr_built', inplace = True, axis = 1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15035 entries, 0 to 15034
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          15035 non-null  float64
#  1   bedrooms       15035 non-null  int64
#  2   bathrooms      15035 non-null  float64
#  3   floors         15035 non-null  float64
#  4   waterfront     15035 non-null  int64
#  5   view           15035 non-null  int64
#  6   condition      15035 non-null  int64
#  7   grade          15035 non-null  int64
#  8   sqft_above     15035 non-null  int64
#  9   sqft_basement  15035 non-null  int64
#  10  lat            15035 non-null  float64
#  11  long           15035 non-null  float64
#  12  sqft_living15  15035 non-null  int64
#  13  sqft_lot15     15035 non-null  int64
#  14  year           15035 non-null  int64
#  15  month          15035 non-null  int64
#  16  weekday        15035 non-null  int64
#  17  house_year     15035 non-null  int64
#  18  renovated      15035 non-null  bool
# dtypes: bool(1), float64(5), int64(13)
# memory usage: 2.1 MB

# %% [markdown]
# ## Data EDA

# %%
fig, ax = plt.subplots(4, 5, figsize=(12, 24))

for idx, column in enumerate(train.columns):
    try:sns.kdeplot(data=train[column], ax = ax[idx // 5 ][idx % 5 ])
    except: sns.barplot(data = train[column], ax = ax[idx // 5 ][idx % 5 ])

# %% [markdown]
# ### 연속형 변수와 이산형 변수를 구분

# %%
for idx, column in enumerate(train.columns):
    print('{} : '.format(column),train[column].unique())
# Out:
# price :  [ 221900.  180000.  510000. ... 1537000.  610685. 1007500.]
# bedrooms :  [ 3  2  5  4  6  1  7  9  8  0 10]
# bathrooms :  [1.   2.   2.25 1.5  2.5  1.75 3.   2.75 3.25 4.   3.5  0.75 4.75 5.
#  4.25 4.5  3.75 5.25 6.   1.25 0.5  5.5  6.75 5.75 0.   8.   7.5  7.75
#  6.25]
# floors :  [1.  2.  1.5 3.  2.5 3.5]
# waterfront :  [0 1]
# view :  [0 3 4 2 1]
# condition :  [3 4 5 2 1]
# grade :  [ 7  6  8  9 10 11 12  5  4  3 13  1]
# sqft_above :  [1180  770 1680 1715 1060 1860  860 1430 1370 1810 1980 1890 1600 1200
#  1250 2330 1070 2450 1710 1750 1400 2320 1510 1090 1280 2360  890 2620
#  2600 3595 1570  990 2290 1000 2830 2250 2420 3250 1590 1260 1540 1110
#  2720 2240 3070 2390  910 3450 2350 1900  960 2660  765 3520 1290 1960
#  1160 1270 2190 1210 1240 3140 2310  700 1080 2520 2780  880 1560 1720
#  1620 1360 1440 2140 1320 1010 1340 1190 1170  940 3670 3540 2500 1760
#  1030 1780 3400 2680 1610 1670 2570 2590  820 1220 2440 1050 2090 1100
#  1420 1690 1130 1910 1350 1940  900 1630 1550 2714 1870 1950 2020 1120
#   980 1480 1230 2280 3760 1640 3530  830 1300  790 2740 1830  720 2010
#  3360 2460 1460 1700 4750 5310  580 2653 2850 2630 3500 1740 1140 2160
#  2270 2650 1330  970 2040 2220 1660 3370 2690  800 2050 2490 2560 1275
#  2580 1390  560 2760 1820 1840 2990 1450 3230 1380 3030 2130 1580 3480
#  2510 3300 3840 1530 2150 1930 2840  833 2000 6070  950 1770 2200 4040
#  1920 1490 3130 2070 2610 3260 2260  430 3150 3390  850  630 3860 2810
#  2380 2120 4030 4410 6050 4740 1040 1970 5403 3350 3580 1790  750 2860
#  2750 2340 2870 3200 1805 4150 1384 3180 3590 2100 2400 1150  870 1470
#  1800 4370 3190 2730 4570 2470 1410  920 2210 4670 4230 2156 1020 2940
#  2030 2910 2060 2640 1730 2710 3100 3610 4270  840 2300  380 2480 3460
#  3060 3000 1654 1500 2790 2430 1520  930 1310 1850 1422  490 3440 4475
# 15032      8        1530              0  47.6993 -122.346           1530
# 15033      8        2310              0  47.5107 -122.362           1830
# 15034      7        1020              0  47.5941 -122.299           1020
#
#        sqft_lot15  year  month  weekday  house_year  renovated
# 0            5650  2014     10        0          67      False
# 1            8062  2015      2        2          89      False
# 2            7503  2015      2        2          35      False
# 3            6819  2014      6        4          27      False
# 4            9711  2015      1        3          59      False
# ...           ...   ...    ...      ...         ...        ...
# 15030        6023  2014     10        1           8      False
# 15031        6200  2015      3        3          13      False
# 15032        1509  2014      5        2          13      False
# 15033        7200  2015      2        0           8      False
# 15034        1357  2014     10        2          14      False
#
# [15035 rows x 19 columns]

# %%
train['long'] = abs(train['long'])
test['long'] = abs(test['long'])

# %%
train[['price','sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15', 'lat', 'long']] = np.log1p(train[['price','sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15', 'lat', 'long']])
test[['sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15', 'lat', 'long']] = np.log1p(test[['sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15', 'lat', 'long']])

# %%
train
# Out:
#            price  bedrooms  bathrooms  floors  waterfront  view  condition  \
# 0      12.309987         3       1.00     1.0           0     0          3
# 1      12.100718         2       1.00     1.0           0     0          3
# 2      13.142168         3       2.00     1.0           0     0          3
# 3      12.458779         3       2.25     2.0           0     0          3
# 4      12.583999         3       1.50     1.0           0     0          3
# ...          ...       ...        ...     ...         ...   ...        ...
# 15030  13.322338         4       2.50     2.0           0     0          3
# 15031  13.822984         4       3.50     2.0           0     0          3
# 15032  12.793862         3       2.50     3.0           0     0          3
# 15033  12.899222         4       2.50     2.0           0     0          3
# 15034  12.691584         2       0.75     2.0           0     0          3
#
#        grade  sqft_above  sqft_basement       lat      long  sqft_living15  \
# 0          7    7.074117       0.000000  3.881795  4.814272       7.201171
# 1          6    6.647688       0.000000  3.886457  4.814077       7.908755
# 2          8    7.427144       0.000000  3.883969  4.812550       7.496097
# 3          7    7.447751       0.000000  3.877632  4.814839       7.713785
# 4          7    6.966967       0.000000  3.879696  4.814742       7.409136
# ...      ...         ...            ...       ...       ...            ...
# 15030      9    7.832411       0.000000  3.881846  4.813541       7.832411
# 15031      9    7.863651       6.814543  3.882670  4.815415       7.626083
# 15032      8    7.333676       0.000000  3.885665  4.814993       7.333676
# 15033      8    7.745436       0.000000  3.881784  4.815123       7.512618
# 15034      7    6.928538       0.000000  3.883502  4.814612       6.928538
#
#        sqft_lot15  year  month  weekday  house_year  renovated
# 0        8.639588  2014     10        0          67      False
# 1        8.995041  2015      2        2          89      False
# 2        8.923191  2015      2        2          35      False
# 3        8.827615  2014      6        4          27      False
# 4        9.181118  2015      1        3          59      False
# ...           ...   ...    ...      ...         ...        ...
# 15030    8.703507  2014     10        1           8      False
# 15031    8.732466  2015      3        3          13      False
# 15032    7.319865  2014      5        2          13      False
# 15033    8.881975  2015      2        0           8      False
# 15034    7.213768  2014     10        2          14      False
#
# [15035 rows x 19 columns]

# %%
col = test.columns

# %%
X_train = train[train.columns.difference(['price'])]
y_train = train['price']
X_test = test

# %%
X_train
# Out:
#        bathrooms  bedrooms  condition  floors  grade  house_year       lat  \
# 0           1.00         3          3     1.0      7          67  3.881795
# 2      11.532051  2014      5        0          21      False
# 3       9.001346  2015      4        2          62      False
# 4       8.932080  2015      3        3          19      False
# ...          ...   ...    ...      ...         ...        ...
# 6463    9.332912  2014      6        3           8      False
# 6464    7.115582  2015      1        0           8      False
# 6465    7.143618  2015      2        3          14      False
# 6466    7.604894  2014      6        0          13      False
# 6467    7.160846  2015      1        4          18      False
#
# [6468 rows x 18 columns]

# %%
X_train = X_train[col]
X_test = X_test[col]

# %% [markdown]
# ## Modeling

# %%
rf = RandomForestRegressor(random_state = 2022)
ada = AdaBoostRegressor(random_state = 2022)
lgb = LGBMRegressor(random_state = 2022)

# %%
def my_GridSearch(model, train, y, param_grid, verbose=2, n_jobs=5):
    grid_model = GridSearchCV(model, param_grid=param_grid, \
                        scoring='neg_mean_squared_error', \
                        cv=5, verbose=verbose, n_jobs=n_jobs)

    grid_model.fit(train, y)
    params = grid_model.cv_results_['params']
    df = pd.DataFrame(params)
    df['score'] = grid_model.cv_results_['mean_test_score']
    df['RMSLE'] = np.sqrt(-1 * df['score'])
    return df.sort_values(by = 'RMSLE', ascending = True)

# %%
rf_param_grid = {
    'n_estimators' : [100, 200, 500, 1000],
#     'max_depth' : [None, 10, 20, 30, 50],
}

# %%
ada_param_grid = {
    'n_estimators':[100, 200, 500, 1000],
    'loss':['linear', 'square', 'exponential'],
    'learning_rate' : [0.001, 0.001, 0.1, 1]    
}

# %%
lgb_param_grid = {
#     'max_depth' : [None, 10, 20, 30, 50],
#     'learning_rate' : [0.001, 0.001, 0.1, 1]   ,
    'n_estimators':[100, 200, 500, 1000],
    'num_leaves' : [10, 20, 30],
    'boosting_type' : ['gbdt', 'dart','goss','rf']    
}

# %% [markdown]
# ### RandomForest

# %%
my_GridSearch(rf, X_train, y_train, rf_param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
#    n_estimators     score     RMSLE
# 3          1000 -0.032780  0.181052
# 2           500 -0.032826  0.181180
# 1           200 -0.032987  0.181624
# 0           100 -0.033261  0.182377

# %% [markdown]
# ### AdaBoost

# %%
my_GridSearch(ada, X_train, y_train, ada_param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
#     learning_rate         loss  n_estimators     score     RMSLE
# 42          1.000       square           500 -0.069748  0.264098
# 41          1.000       square           200 -0.069895  0.264377
# 43          1.000       square          1000 -0.070059  0.264686
# 40          1.000       square           100 -0.070099  0.264762
# 33          0.100  exponential           200 -0.070545  0.265604
# 44          1.000  exponential           100 -0.070805  0.266092
# 34          0.100  exponential           500 -0.071019  0.266495
# 36          1.000       linear           100 -0.071326  0.267070
# 25          0.100       linear           200 -0.071778  0.267914
# 26          0.100       linear           500 -0.071884  0.268113
# 27          0.100       linear          1000 -0.072307  0.268900
# 35          0.100  exponential          1000 -0.072404  0.269079
# 37          1.000       linear           200 -0.072415  0.269100
# 45          1.000  exponential           200 -0.072521  0.269297
# 24          0.100       linear           100 -0.072930  0.270055
# 32          0.100  exponential           100 -0.072992  0.270171
# 38          1.000       linear           500 -0.073042  0.270263
# 30          0.100       square           500 -0.073195  0.270547
# 31          0.100       square          1000 -0.073261  0.270668
# 39          1.000       linear          1000 -0.073612  0.271315
# 46          1.000  exponential           500 -0.073720  0.271514
# 47          1.000  exponential          1000 -0.074479  0.272908
# 29          0.100       square           200 -0.074724  0.273357
# 28          0.100       square           100 -0.075441  0.274665
# 15          0.001       linear          1000 -0.094982  0.308192
# 3           0.001       linear          1000 -0.094982  0.308192
# 7           0.001       square          1000 -0.095030  0.308270
# 19          0.001       square          1000 -0.095030  0.308270
# 23          0.001  exponential          1000 -0.095991  0.309824
# 11          0.001  exponential          1000 -0.095991  0.309824
# 18          0.001       square           500 -0.097795  0.312722
# 6           0.001       square           500 -0.097795  0.312722
# 2           0.001       linear           500 -0.097842  0.312797
# 14          0.001       linear           500 -0.097842  0.312797
# 10          0.001  exponential           500 -0.098431  0.313737
# 22          0.001  exponential           500 -0.098431  0.313737
# 1           0.001       linear           200 -0.099217  0.314987
# 13          0.001       linear           200 -0.099217  0.314987
# 17          0.001       square           200 -0.099237  0.315019
# 5           0.001       square           200 -0.099237  0.315019
# 21          0.001  exponential           200 -0.099308  0.315132
# 9           0.001  exponential           200 -0.099308  0.315132
# 12          0.001       linear           100 -0.099494  0.315426
# 0           0.001       linear           100 -0.099494  0.315426
# 20          0.001  exponential           100 -0.099599  0.315593
# 8           0.001  exponential           100 -0.099599  0.315593
# 4           0.001       square           100 -0.099632  0.315646
# 16          0.001       square           100 -0.099632  0.315646

# %% [markdown]
# ### LightGBM

# %%
my_GridSearch(lgb, X_train, y_train, lgb_param_grid, verbose=2, n_jobs=5)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END ...................................n_estimators=100; total time=  15.1s
# [CV] END ...................................n_estimators=200; total time=  41.0s
# [CV] END ...................................n_estimators=500; total time= 1.6min
# [CV] END ..................................n_estimators=1000; total time= 3.0min
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=100; total time=  11.8s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=200; total time=  24.8s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=500; total time=  54.8s
# [CV] END learning_rate=0.001, loss=linear, n_estimators=1000; total time= 1.9min
# [CV] END .learning_rate=0.001, loss=square, n_estimators=100; total time=  10.9s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=200; total time=  20.3s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=500; total time=  54.8s
# [CV] END learning_rate=0.001, loss=square, n_estimators=1000; total time= 1.7min
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=100; total time=   9.5s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=100; total time=  13.4s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=100; total time=   9.4s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=200; total time=  23.5s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=500; total time=  52.2s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=1000; total time= 1.7min
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=100; total time=   9.4s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=100; total time=  12.2s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=100; total time=  16.0s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=200; total time=  27.3s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=500; total time= 1.1min
# [CV] END learning_rate=0.001, loss=linear, n_estimators=1000; total time= 1.8min
# [CV] END .learning_rate=0.001, loss=square, n_estimators=100; total time=  13.7s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=200; total time=  25.1s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=500; total time=  58.2s
# [CV] END learning_rate=0.001, loss=square, n_estimators=1000; total time= 1.8min
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=100; total time=  13.3s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=200; total time=  21.3s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=500; total time=  53.9s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=1000; total time= 1.9min
# [CV] END ...learning_rate=0.1, loss=linear, n_estimators=100; total time=  11.5s
# [CV] END ...learning_rate=0.1, loss=linear, n_estimators=200; total time=  23.2s
# [CV] END ...learning_rate=0.1, loss=linear, n_estimators=500; total time=  53.4s
# [CV] END ..learning_rate=0.1, loss=linear, n_estimators=1000; total time= 1.7min
# [CV] END ...learning_rate=0.1, loss=square, n_estimators=200; total time=  18.0s
# [CV] END ...learning_rate=0.1, loss=square, n_estimators=500; total time=  43.1s
# [CV] END ..learning_rate=0.1, loss=square, n_estimators=1000; total time= 1.4min
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=100; total time=  16.5s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=100; total time=  11.3s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=200; total time=  26.6s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=500; total time=  54.7s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=1000; total time= 1.8min
# [CV] END .....learning_rate=1, loss=linear, n_estimators=200; total time=  17.7s
# [CV] END .....learning_rate=1, loss=linear, n_estimators=200; total time=  19.7s
# [CV] END .....learning_rate=1, loss=linear, n_estimators=500; total time=  51.5s
# [CV] END ....learning_rate=1, loss=linear, n_estimators=1000; total time= 1.2min
# [CV] END .....learning_rate=1, loss=square, n_estimators=200; total time=  19.3s
# [CV] END .....learning_rate=1, loss=square, n_estimators=500; total time=  44.8s
# [CV] END ....learning_rate=1, loss=square, n_estimators=1000; total time= 1.4min
# [CV] END learning_rate=1, loss=exponential, n_estimators=200; total time=  17.4s
# [CV] END learning_rate=1, loss=exponential, n_estimators=500; total time=  41.1s
# [CV] END learning_rate=1, loss=exponential, n_estimators=1000; total time= 1.3min
# [CV] END boosting_type=gbdt, n_estimators=100, num_leaves=10; total time=   0.6s
# [CV] END boosting_type=gbdt, n_estimators=100, num_leaves=20; total time=   0.4s
# [CV] END boosting_type=gbdt, n_estimators=100, num_leaves=30; total time=   1.0s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=10; total time=   0.6s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=20; total time=   0.8s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=30; total time=   0.9s
# [CV] END boosting_type=gbdt, n_estimators=500, num_leaves=10; total time=   1.1s
# [CV] END boosting_type=gbdt, n_estimators=500, num_leaves=20; total time=   1.6s
# [CV] END boosting_type=gbdt, n_estimators=500, num_leaves=30; total time=   2.0s
# [CV] END boosting_type=gbdt, n_estimators=500, num_leaves=30; total time=   2.3s
# [CV] END boosting_type=gbdt, n_estimators=1000, num_leaves=10; total time=   4.0s
# [CV] END boosting_type=gbdt, n_estimators=1000, num_leaves=30; total time=   3.8s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=10; total time=   0.7s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=10; total time=   0.7s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=10; total time=   0.7s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=10; total time=   0.7s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=20; total time=   1.1s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=30; total time=   1.2s
# [CV] END boosting_type=dart, n_estimators=200, num_leaves=10; total time=   2.7s
# [CV] END boosting_type=dart, n_estimators=200, num_leaves=20; total time=   3.1s
# [CV] END boosting_type=dart, n_estimators=200, num_leaves=30; total time=   5.4s
# [CV] END boosting_type=dart, n_estimators=500, num_leaves=10; total time=  14.2s
# [CV] END boosting_type=dart, n_estimators=500, num_leaves=20; total time=  21.2s
# [CV] END boosting_type=dart, n_estimators=500, num_leaves=30; total time=  22.1s
# [CV] END boosting_type=dart, n_estimators=1000, num_leaves=10; total time=  36.1s
# [CV] END boosting_type=dart, n_estimators=1000, num_leaves=20; total time=  54.4s
# [CV] END boosting_type=dart, n_estimators=1000, num_leaves=30; total time= 1.0min
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=10; total time=   0.8s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=10; total time=   0.8s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=10; total time=   0.7s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=10; total time=   0.4s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=10; total time=   0.4s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=20; total time=   0.5s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=20; total time=   0.6s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=20; total time=   0.5s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=30; total time=   0.6s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=30; total time=   0.6s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=30; total time=   0.6s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=10; total time=   0.8s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=10; total time=   0.9s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=10; total time=   0.9s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=20; total time=   1.6s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=20; total time=   1.9s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=30; total time=   1.9s
# [CV] END boosting_type=goss, n_estimators=500, num_leaves=10; total time=   2.2s
# [CV] END boosting_type=goss, n_estimators=500, num_leaves=20; total time=   2.3s
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
# [CV] END ...................................n_estimators=100; total time=  18.5s
# [CV] END ...................................n_estimators=200; total time=  33.8s
# [CV] END ...................................n_estimators=500; total time= 1.5min
# [CV] END ..................................n_estimators=1000; total time= 3.1min
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=100; total time=  13.1s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=200; total time=  24.3s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=500; total time= 1.0min
# [CV] END learning_rate=0.001, loss=linear, n_estimators=1000; total time= 2.0min
# [CV] END .learning_rate=0.001, loss=square, n_estimators=200; total time=  23.7s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=500; total time=  59.5s
# [CV] END learning_rate=0.001, loss=square, n_estimators=1000; total time= 2.2min
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=200; total time=  20.4s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=500; total time=  56.1s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=1000; total time= 2.0min
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=200; total time=  19.7s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=500; total time= 1.0min
# [CV] END learning_rate=0.001, loss=linear, n_estimators=1000; total time= 2.0min
# [CV] END .learning_rate=0.001, loss=square, n_estimators=100; total time=  12.9s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=200; total time=  25.8s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=500; total time=  59.3s
# [CV] END learning_rate=0.001, loss=square, n_estimators=1000; total time= 1.9min
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=100; total time=   9.8s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=200; total time=  22.3s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=500; total time= 1.0min
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=1000; total time= 2.0min
# [CV] END ...learning_rate=0.1, loss=linear, n_estimators=200; total time=  18.3s
# [CV] END ...learning_rate=0.1, loss=linear, n_estimators=500; total time=  46.5s
# [CV] END ..learning_rate=0.1, loss=linear, n_estimators=1000; total time= 1.6min
# [CV] END ...learning_rate=0.1, loss=square, n_estimators=100; total time=  15.9s
# [CV] END ...learning_rate=0.1, loss=square, n_estimators=200; total time=  19.1s
# [CV] END ...learning_rate=0.1, loss=square, n_estimators=500; total time=  48.5s
# [CV] END ..learning_rate=0.1, loss=square, n_estimators=1000; total time= 1.3min
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=100; total time=  10.3s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=100; total time=  12.2s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=200; total time=  21.7s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=500; total time=  58.3s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=1000; total time= 1.8min
# [CV] END .....learning_rate=1, loss=linear, n_estimators=100; total time=  10.0s
# [CV] END .....learning_rate=1, loss=linear, n_estimators=200; total time=  17.2s
# [CV] END .....learning_rate=1, loss=linear, n_estimators=500; total time=  40.9s
# [CV] END ....learning_rate=1, loss=linear, n_estimators=1000; total time= 1.4min
# [CV] END .....learning_rate=1, loss=square, n_estimators=100; total time=   8.0s
# [CV] END .....learning_rate=1, loss=square, n_estimators=100; total time=   8.7s
# [CV] END .....learning_rate=1, loss=square, n_estimators=200; total time=  16.8s
# [CV] END .....learning_rate=1, loss=square, n_estimators=500; total time=  40.1s
# [CV] END ....learning_rate=1, loss=square, n_estimators=1000; total time= 1.5min
# [CV] END learning_rate=1, loss=exponential, n_estimators=200; total time=  17.4s
# [CV] END learning_rate=1, loss=exponential, n_estimators=500; total time=  43.2s
# [CV] END learning_rate=1, loss=exponential, n_estimators=1000; total time= 1.3min
# [CV] END boosting_type=gbdt, n_estimators=100, num_leaves=10; total time=   0.9s
# [CV] END boosting_type=gbdt, n_estimators=100, num_leaves=30; total time=   0.6s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=10; total time=   0.6s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=20; total time=   0.7s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=20; total time=   0.8s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=30; total time=   0.9s
# [CV] END boosting_type=gbdt, n_estimators=500, num_leaves=10; total time=   2.3s
# [CV] END boosting_type=gbdt, n_estimators=500, num_leaves=20; total time=   2.6s
# [CV] END boosting_type=gbdt, n_estimators=1000, num_leaves=10; total time=   2.3s
# [CV] END boosting_type=gbdt, n_estimators=1000, num_leaves=20; total time=   3.0s
# [CV] END boosting_type=gbdt, n_estimators=1000, num_leaves=20; total time=   3.0s
# [CV] END boosting_type=gbdt, n_estimators=1000, num_leaves=30; total time=   5.0s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=20; total time=   1.0s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=30; total time=   1.5s
# [CV] END boosting_type=dart, n_estimators=200, num_leaves=10; total time=   2.3s
# [CV] END boosting_type=dart, n_estimators=200, num_leaves=20; total time=   3.1s
# [CV] END boosting_type=dart, n_estimators=200, num_leaves=30; total time=   4.9s
# [CV] END boosting_type=dart, n_estimators=500, num_leaves=10; total time=  11.4s
# [CV] END boosting_type=dart, n_estimators=500, num_leaves=20; total time=  23.7s
# [CV] END boosting_type=dart, n_estimators=500, num_leaves=30; total time=  24.5s
# [CV] END boosting_type=dart, n_estimators=1000, num_leaves=10; total time=  40.8s
# [CV] END boosting_type=dart, n_estimators=1000, num_leaves=20; total time=  52.7s
# [CV] END boosting_type=dart, n_estimators=1000, num_leaves=30; total time= 1.0min
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=20; total time=   0.5s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=20; total time=   1.1s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=30; total time=   0.8s
# [CV] END boosting_type=goss, n_estimators=100, num_leaves=30; total time=   1.2s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=10; total time=   0.8s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=10; total time=   0.8s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=20; total time=   1.1s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=20; total time=   1.1s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=30; total time=   1.9s
# [CV] END boosting_type=goss, n_estimators=200, num_leaves=30; total time=   1.1s
# [CV] END boosting_type=goss, n_estimators=500, num_leaves=10; total time=   3.2s
# [CV] END boosting_type=goss, n_estimators=500, num_leaves=20; total time=   4.0s
# [CV] END boosting_type=goss, n_estimators=500, num_leaves=30; total time=   3.9s
# [CV] END boosting_type=goss, n_estimators=1000, num_leaves=10; total time=   3.9s
# [CV] END boosting_type=goss, n_estimators=1000, num_leaves=10; total time=   5.5s
# [CV] END boosting_type=goss, n_estimators=1000, num_leaves=30; total time=   6.5s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=10; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=10; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=10; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=10; total time=   0.2s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=20; total time=   0.2s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=20; total time=   0.2s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=20; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=30; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=30; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=30; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=200, num_leaves=10; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=200, num_leaves=10; total time=   0.1s
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
#
# [LightGBM] [Fatal] Check failed: config->bagging_freq > 0 && config->bagging_fraction < 1.0f && config->bagging_fraction > 0.0f at /__w/1/s/python-package/compile/src/boosting/rf.hpp, line 35 .
# [CV] END ...................................n_estimators=100; total time=  16.9s
# [CV] END ...................................n_estimators=200; total time=  35.4s
# [CV] END ...................................n_estimators=500; total time= 1.4min
# [CV] END ..................................n_estimators=1000; total time= 3.1min
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=100; total time=   9.2s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=200; total time=  28.9s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=500; total time=  59.0s
# [CV] END learning_rate=0.001, loss=linear, n_estimators=1000; total time= 1.9min
# [CV] END .learning_rate=0.001, loss=square, n_estimators=100; total time=  10.4s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=200; total time=  24.0s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=500; total time=  59.1s
# [CV] END learning_rate=0.001, loss=square, n_estimators=1000; total time= 1.8min
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=100; total time=  10.9s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=100; total time=  13.0s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=200; total time=  26.9s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=500; total time= 1.0min
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=1000; total time= 2.1min
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=200; total time=  20.7s
# [CV] END .learning_rate=0.001, loss=linear, n_estimators=500; total time= 1.0min
# [CV] END learning_rate=0.001, loss=linear, n_estimators=1000; total time= 1.9min
# [CV] END .learning_rate=0.001, loss=square, n_estimators=200; total time=  19.4s
# [CV] END .learning_rate=0.001, loss=square, n_estimators=500; total time=  49.5s
# [CV] END learning_rate=0.001, loss=square, n_estimators=1000; total time= 1.9min
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=100; total time=  17.1s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=100; total time=  13.9s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=200; total time=  25.5s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=500; total time=  59.9s
# [CV] END learning_rate=0.001, loss=exponential, n_estimators=1000; total time= 2.0min
# [CV] END ...learning_rate=0.1, loss=linear, n_estimators=200; total time=  19.4s
# [CV] END ...learning_rate=0.1, loss=linear, n_estimators=500; total time=  46.0s
# [CV] END ..learning_rate=0.1, loss=linear, n_estimators=1000; total time= 1.7min
# [CV] END ...learning_rate=0.1, loss=square, n_estimators=100; total time=  13.8s
# [CV] END ...learning_rate=0.1, loss=square, n_estimators=200; total time=  23.0s
# [CV] END ...learning_rate=0.1, loss=square, n_estimators=500; total time=  43.6s
# [CV] END ..learning_rate=0.1, loss=square, n_estimators=1000; total time= 1.5min
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=200; total time=  22.3s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=500; total time=  58.6s
# [CV] END learning_rate=0.1, loss=exponential, n_estimators=1000; total time= 1.6min
# [CV] END .....learning_rate=1, loss=linear, n_estimators=100; total time=  10.7s
# [CV] END .....learning_rate=1, loss=linear, n_estimators=100; total time=  13.1s
# [CV] END .....learning_rate=1, loss=linear, n_estimators=200; total time=  18.4s
# [CV] END .....learning_rate=1, loss=linear, n_estimators=500; total time=  45.5s
# [CV] END ....learning_rate=1, loss=linear, n_estimators=1000; total time= 1.6min
# [CV] END .....learning_rate=1, loss=square, n_estimators=100; total time=  10.8s
# [CV] END .....learning_rate=1, loss=square, n_estimators=200; total time=  14.9s
# [CV] END .....learning_rate=1, loss=square, n_estimators=500; total time=  46.7s
# [CV] END ....learning_rate=1, loss=square, n_estimators=1000; total time= 1.2min
# [CV] END learning_rate=1, loss=exponential, n_estimators=100; total time=  10.7s
# [CV] END learning_rate=1, loss=exponential, n_estimators=200; total time=  16.9s
# [CV] END learning_rate=1, loss=exponential, n_estimators=500; total time=  39.2s
# [CV] END learning_rate=1, loss=exponential, n_estimators=1000; total time= 1.3min
# [CV] END boosting_type=gbdt, n_estimators=100, num_leaves=10; total time=   0.4s
# [CV] END boosting_type=gbdt, n_estimators=100, num_leaves=20; total time=   0.5s
# [CV] END boosting_type=gbdt, n_estimators=100, num_leaves=30; total time=   0.6s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=10; total time=   0.6s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=10; total time=   1.0s
# [CV] END boosting_type=gbdt, n_estimators=200, num_leaves=30; total time=   1.6s
# [CV] END boosting_type=gbdt, n_estimators=500, num_leaves=10; total time=   2.0s
# [CV] END boosting_type=gbdt, n_estimators=500, num_leaves=20; total time=   1.8s
# [CV] END boosting_type=gbdt, n_estimators=500, num_leaves=30; total time=   2.3s
# [CV] END boosting_type=gbdt, n_estimators=1000, num_leaves=10; total time=   2.3s
# [CV] END boosting_type=gbdt, n_estimators=1000, num_leaves=20; total time=   4.3s
# [CV] END boosting_type=gbdt, n_estimators=1000, num_leaves=30; total time=   5.0s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=20; total time=   1.8s
# [CV] END boosting_type=dart, n_estimators=100, num_leaves=30; total time=   1.3s
# [CV] END boosting_type=dart, n_estimators=200, num_leaves=10; total time=   4.6s
# [CV] END boosting_type=dart, n_estimators=200, num_leaves=20; total time=   3.3s
# [CV] END boosting_type=dart, n_estimators=200, num_leaves=30; total time=   7.3s
# [CV] END boosting_type=dart, n_estimators=500, num_leaves=10; total time=  14.8s
# [CV] END boosting_type=dart, n_estimators=500, num_leaves=20; total time=  22.1s
# [CV] END boosting_type=dart, n_estimators=500, num_leaves=30; total time=  24.8s
# [CV] END boosting_type=dart, n_estimators=1000, num_leaves=10; total time=  38.4s
# [CV] END boosting_type=dart, n_estimators=1000, num_leaves=20; total time= 1.0min
# [CV] END boosting_type=dart, n_estimators=1000, num_leaves=30; total time= 1.1min
# [CV] END boosting_type=goss, n_estimators=500, num_leaves=20; total time=   2.3s
# [CV] END boosting_type=goss, n_estimators=500, num_leaves=30; total time=   3.1s
# [CV] END boosting_type=goss, n_estimators=1000, num_leaves=10; total time=   4.3s
# [CV] END boosting_type=goss, n_estimators=1000, num_leaves=20; total time=   4.7s
# [CV] END boosting_type=goss, n_estimators=1000, num_leaves=30; total time=   6.1s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=10; total time=   0.2s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=20; total time=   0.2s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=20; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=30; total time=   0.2s
# [CV] END ..boosting_type=rf, n_estimators=100, num_leaves=30; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=200, num_leaves=10; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=200, num_leaves=10; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=200, num_leaves=20; total time=   0.2s
# [CV] END ..boosting_type=rf, n_estimators=200, num_leaves=20; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=200, num_leaves=30; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=200, num_leaves=30; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=500, num_leaves=10; total time=   0.2s
# [CV] END ..boosting_type=rf, n_estimators=500, num_leaves=10; total time=   0.2s
# [CV] END ..boosting_type=rf, n_estimators=500, num_leaves=20; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=500, num_leaves=30; total time=   0.1s
# [CV] END ..boosting_type=rf, n_estimators=500, num_leaves=30; total time=   0.1s
# [CV] END .boosting_type=rf, n_estimators=1000, num_leaves=10; total time=   0.1s
# [CV] END .boosting_type=rf, n_estimators=1000, num_leaves=10; total time=   0.2s
# [CV] END .boosting_type=rf, n_estimators=1000, num_leaves=20; total time=   0.1s
# [CV] END .boosting_type=rf, n_estimators=1000, num_leaves=20; total time=   0.1s
# [CV] END .boosting_type=rf, n_estimators=1000, num_leaves=30; total time=   0.1s
#    boosting_type  n_estimators  num_leaves     score     RMSLE
# 9           gbdt          1000          10 -0.027386  0.165487
# 7           gbdt           500          20 -0.027466  0.165729
# 6           gbdt           500          10 -0.027568  0.166036
# 5           gbdt           200          30 -0.027575  0.166058
# 4           gbdt           200          20 -0.027725  0.166509
# 8           gbdt           500          30 -0.027818  0.166788
# 30          goss           500          10 -0.027823  0.166803
# 10          gbdt          1000          20 -0.027951  0.167185
# 28          goss           200          20 -0.028039  0.167448
# 29          goss           200          30 -0.028228  0.168013
# 2           gbdt           100          30 -0.028236  0.168037
# 33          goss          1000          10 -0.028237  0.168039
# 31          goss           500          20 -0.028270  0.168137
# 11          gbdt          1000          30 -0.028426  0.168599
# 26          goss           100          30 -0.028456  0.168688
# 1           gbdt           100          20 -0.028707  0.169432
# 27          goss           200          10 -0.028781  0.169650
# 25          goss           100          20 -0.028840  0.169825
# 3           gbdt           200          10 -0.028935  0.170101
# 34          goss          1000          20 -0.029253  0.171034
# 32          goss           500          30 -0.029305  0.171187
# 35          goss          1000          30 -0.030479  0.174581
# 24          goss           100          10 -0.030705  0.175228
# 0           gbdt           100          10 -0.031037  0.176173
# 20          dart           500          30 -0.043085  0.207570
# 19          dart           500          20 -0.043363  0.208238
# 23          dart          1000          30 -0.043724  0.209104
# 22          dart          1000          20 -0.043809  0.209306
# 21          dart          1000          10 -0.044218  0.210281
# 18          dart           500          10 -0.044980  0.212084
# 17          dart           200          30 -0.894996  0.946042
# 16          dart           200          20 -0.895163  0.946130
# 15          dart           200          10 -0.898578  0.947933
# 14          dart           100          30 -1.471793  1.213175
# 13          dart           100          20 -1.471985  1.213254
# 12          dart           100          10 -1.477067  1.215347
# 36            rf           100          10       NaN       NaN
# 37            rf           100          20       NaN       NaN
# 38            rf           100          30       NaN       NaN
# 39            rf           200          10       NaN       NaN
# 40            rf           200          20       NaN       NaN
# 41            rf           200          30       NaN       NaN
# 42            rf           500          10       NaN       NaN
# 43            rf           500          20       NaN       NaN
# 44            rf           500          30       NaN       NaN
# 45            rf          1000          10       NaN       NaN
# 46            rf          1000          20       NaN       NaN
# 47            rf          1000          30       NaN       NaN

# %%
def save_submission(model, train, y, test, model_name, rmsle):
    prediction = model.predict(test)
    prediction = np.expm1(prediction)
    
    data_dir = os.getenv('HOME')+'/aiffel/exp5/data'

    submission_path = join(data_dir, 'sample_submission.csv')
    submission = pd.read_csv(submission_path)
    submission['price'] = prediction
    submission_csv_path = '{}/submission_{}_RMSLE_{}.csv'.format(data_dir, model_name, rmsle)
    submission.to_csv(submission_csv_path, index=False)

# %%
model = RandomForestRegressor(n_estimators=1000, random_state = 2022)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=2022)

# %%
save_submission(model, X_train, y_train, X_test, model.__class__.__name__, rmsle='0.181052')

# %% [markdown]
# ### Score : 138221.98186

# %%
model = AdaBoostRegressor(learning_rate= 1.000, loss = 'square', n_estimators=500)

# %%
model.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(loss='square', n_estimators=500)

# %%
save_submission(model, X_train, y_train, X_test, model.__class__.__name__, rmsle='0.264098')

# %% [markdown]
# ### Score : 197681.35705

# %%
model = LGBMRegressor(boosting_type='gbdt', n_estimators=1000, num_leaves = 10)

# %%
model.fit(X_train, y_train)
# Out:
# LGBMRegressor(n_estimators=1000, num_leaves=10)

# %%
save_submission(model, X_train, y_train, X_test, model.__class__.__name__, rmsle='0.165487')

# %% [markdown]
# ### Score : 109707.31187
